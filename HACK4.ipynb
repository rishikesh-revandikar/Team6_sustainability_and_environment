# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikesh-revandikar/Team6_sustainability_and_environment/blob/main/HACK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df1 = pd.read_csv('/content/drive/MyDrive/HACK/newData/merged_df_all.csv')
df1
# Out:
#        Unnamed: 0.1  Unnamed: 0                 DateTime  \
# 0                 0           0  2019-01-01 01:00:00.000
# 1                 1           1  2019-01-01 02:00:00.000
# 2                 2           2  2019-01-01 03:00:00.005
# 3                 3           3  2019-01-01 04:00:00.010
# 4                 4           4  2019-01-01 05:00:00.015
# ...             ...         ...                      ...
# 43818         43818        8755      2023-12-31 19:00:00
# 43819         43819        8756      2023-12-31 20:00:00
# 43820         43820        8757      2023-12-31 21:00:00
# 43821         43821        8758      2023-12-31 22:00:00
# 43822         43822        8759      2023-12-31 23:00:00
#
#        Air temperature | (°C)  Power generated by system | (MW)  \
# 0                      10.926                           33.6881
# 1                       9.919                           37.2619
# 2                       8.567                           30.5029
# 3                       7.877                           28.4192
# 4                       7.259                           27.3703
# ...                       ...                               ...
# 43818                  11.713                           30.4221
# 43819                  12.115                           32.0366
# 43820                  11.856                           36.3990
# 43821                  10.761                           37.7404
# 43822                   8.380                           36.7908
#
#        Pressure | (atm)  Wind speed | (m/s)
# 0              0.979103               9.014
# 1              0.979566               9.428
# 2              0.979937               8.700
# 3              0.980053               8.481
# 4              0.979867               8.383
# ...                 ...                 ...
# 43818          0.985015               8.703
# 43819          0.985244               8.854
# 43820          0.985639               9.333
# 43821          0.986212               9.457
# 43822          0.987183               9.324
#
# [43823 rows x 7 columns]

# %%
df1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'DateTime', 'Air temperature | (°C)',
#        'Power generated by system | (MW)', 'Pressure | (atm)',
#        'Wind speed | (m/s)'],
#       dtype='object')

# %%
df1.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df1
# Out:
#                       DateTime  Air temperature | (°C)  \
# 0      2019-01-01 01:00:00.000                  10.926
# 1      2019-01-01 02:00:00.000                   9.919
# 2      2019-01-01 03:00:00.005                   8.567
# 3      2019-01-01 04:00:00.010                   7.877
# 4      2019-01-01 05:00:00.015                   7.259
# ...                        ...                     ...
# 43818      2023-12-31 19:00:00                  11.713
# 43819      2023-12-31 20:00:00                  12.115
# 43820      2023-12-31 21:00:00                  11.856
# 43821      2023-12-31 22:00:00                  10.761
# 43822      2023-12-31 23:00:00                   8.380
#
#        Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)
# 0                               33.6881          0.979103               9.014
# 1                               37.2619          0.979566               9.428
# 2                               30.5029          0.979937               8.700
# 3                               28.4192          0.980053               8.481
# 4                               27.3703          0.979867               8.383
# ...                                 ...               ...                 ...
# 43818                           30.4221          0.985015               8.703
# 43819                           32.0366          0.985244               8.854
# 43820                           36.3990          0.985639               9.333
# 43821                           37.7404          0.986212               9.457
# 43822                           36.7908          0.987183               9.324
#
# [43823 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['DateTime', 'Air temperature | (°C)',
#        'Power generated by system | (MW)', 'Pressure | (atm)',
#        'Wind speed | (m/s)'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

X = df1[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)']]
y = df1['Power generated by system | (MW)']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model = RandomForestRegressor(n_estimators=100, random_state=42)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print(f"Mean squared error: {mse}")
# Out:
# Mean squared error: 0.08492516228096765

# %%
y_pred
# Out:
# array([ 3.6762629,  3.5998509,  4.2802676, ..., 12.02279  , 32.659964 ,
#        12.973374 ])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.9997209061024027

# %%
mon_3 = pd.read_excel('/content/drive/MyDrive/HACK/Hackathon_data/wind_power_data/wind_power_gen_3months_validation_data.xlsx')
mon_3
# Out:
#                 DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0    2024-01-01 00:00:00                   6.609          0.988077
# 1    2024-01-01 01:00:00                   5.257          0.988969
# 2    2024-01-01 02:00:00                   4.374          0.989708
# 3    2024-01-01 03:00:00                   2.913          0.990171
# 4    2024-01-01 04:00:00                   1.152          0.990264
# ...                  ...                     ...               ...
# 2179 2024-03-31 19:00:00                  27.835          0.973886
# 2180 2024-03-31 20:00:00                  28.390          0.973506
# 2181 2024-03-31 21:00:00                  28.487          0.973034
# 2182 2024-03-31 22:00:00                  28.555          0.972540
# 2183 2024-03-31 23:00:00                  27.944          0.972353
#
#       Wind speed | (m/s)  Power generated by system | (MW)
# 0                 10.868                          53.18100
# 1                 10.679                          51.90830
# 2                 11.200                          56.35400
# 3                 10.962                          54.93680
# 4                 11.307                          57.74310
# ...                  ...                               ...
# 2179               4.855                           3.49390
# 2180               6.066                           8.96133
# 2181               7.075                          15.10510
# 2182               6.892                          13.70680
# 2183               6.785                          12.94460
#
# [2184 rows x 5 columns]

# %%
X_val = mon_3[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)']]
y_pred_val = model.predict(X_val)
print(y_pred_val)
# Out:
# [53.088237 51.467859 56.16945  ... 15.168383 13.670668 12.860713]

# %%
r2 = r2_score(mon_3['Power generated by system | (MW)'], y_pred_val)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.9999060879383102

# %%
df1
# Out:
#                       DateTime  Air temperature | (°C)  \
# 0      2019-01-01 01:00:00.000                  10.926
# 1      2019-01-01 02:00:00.000                   9.919
# 2      2019-01-01 03:00:00.005                   8.567
# 3      2019-01-01 04:00:00.010                   7.877
# 4      2019-01-01 05:00:00.015                   7.259
# ...                        ...                     ...
# 43818      2023-12-31 19:00:00                  11.713
# 43819      2023-12-31 20:00:00                  12.115
# 43820      2023-12-31 21:00:00                  11.856
# 43821      2023-12-31 22:00:00                  10.761
# 43822      2023-12-31 23:00:00                   8.380
#
#        Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)
# 0                               33.6881          0.979103               9.014
# 1                               37.2619          0.979566               9.428
# 2                               30.5029          0.979937               8.700
# 3                               28.4192          0.980053               8.481
# 4                               27.3703          0.979867               8.383
# ...                                 ...               ...                 ...
# 43818                           30.4221          0.985015               8.703
# 43819                           32.0366          0.985244               8.854
# 43820                           36.3990          0.985639               9.333
# 43821                           37.7404          0.986212               9.457
# 43822                           36.7908          0.987183               9.324
#
# [43823 rows x 5 columns]
