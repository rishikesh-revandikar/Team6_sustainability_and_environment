# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikesh-revandikar/Team6_sustainability_and_environment/blob/main/HACK5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# get the data from four xlxs file  and merge it acc to DateTime 2019
import pandas as pd

# Read the four Excel files
df1 = pd.read_csv('/content/drive/MyDrive/HACK/gen Data/merged_df_all.csv')
df1
# Out:
#        Unnamed: 0.1  Unnamed: 0                 DateTime  \
# 0                 0           0  2019-01-01 01:00:00.000
# 1                 1           1  2019-01-01 02:00:00.000
# 2                 2           2  2019-01-01 03:00:00.005
# 3                 3           3  2019-01-01 04:00:00.010
# 4                 4           4  2019-01-01 05:00:00.015
# ...             ...         ...                      ...
# 43790         43790        8754  2019-12-31 19:00:00.000
# 43791         43791        8755  2019-12-31 20:00:00.000
# 43792         43792        8756  2019-12-31 21:00:00.000
# 43793         43793        8757  2019-12-31 22:00:00.000
# 43794         43794        8758  2019-12-31 23:00:00.000
#
#        Air temperature | (°C)  Power generated by system | (MW)  \
# 0                      10.926                          33.68810
# 1                       9.919                          37.26190
# 2                       8.567                          30.50290
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'DateTime', 'Air temperature | (°C)',
#        'Power generated by system | (MW)', 'Pressure | (atm)',
#        'Wind speed | (m/s)'],
#       dtype='object')

# %%
# prompt: drop column 'Unnamed: 0.1', 'Unnamed: 0'

df1.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
df1
# Out:
#                       DateTime  Air temperature | (°C)  \
# 0      2019-01-01 01:00:00.000                  10.926
# 1      2019-01-01 02:00:00.000                   9.919
# 2      2019-01-01 03:00:00.005                   8.567
# 3      2019-01-01 04:00:00.010                   7.877
# 4      2019-01-01 05:00:00.015                   7.259
# ...                        ...                     ...
# 43790  2019-12-31 19:00:00.000                  11.514
# 43791  2019-12-31 20:00:00.000                  12.143
# 43792  2019-12-31 21:00:00.000                  12.208
# 43793  2019-12-31 22:00:00.000                  11.031
# 43794  2019-12-31 23:00:00.000                   7.066
#
#        Power generated by system | (MW)  Pressure | (atm)  Wind speed | (m/s)
# 0                              33.68810          0.979103               9.014
# 1                              37.26190          0.979566               9.428
# ...

# %%
df1.columns
# Out:
# Index(['DateTime', 'Air temperature | (°C)',
#        'Power generated by system | (MW)', 'Pressure | (atm)',
#        'Wind speed | (m/s)'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Separate features and target
X = df1[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)']]
y = df1['Power generated by system | (MW)']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Create a Random Forest regressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model on the training set
model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test)

# Evaluate the model
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print(f"Mean squared error: {mse}")
# Out:
# Mean squared error: 0.0018046682225016139

# %%
y_pred
# Out:
# array([ 0.       ,  0.       ,  2.2434986, ..., 16.402927 , 18.722052 ,
#        44.852466 ])

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.999993443336964

# %%
mon_3 = pd.read_excel('/content/drive/MyDrive/HACK/Hackathon_data/wind_power_data/wind_power_gen_3months_validation_data.xlsx')
mon_3
# Out:
#                 DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0    2024-01-01 00:00:00                   6.609          0.988077
# 1    2024-01-01 01:00:00                   5.257          0.988969
# 2    2024-01-01 02:00:00                   4.374          0.989708
# 3    2024-01-01 03:00:00                   2.913          0.990171
# 4    2024-01-01 04:00:00                   1.152          0.990264
# ...                  ...                     ...               ...
# 2179 2024-03-31 19:00:00                  27.835          0.973886
# 2180 2024-03-31 20:00:00                  28.390          0.973506
# 2181 2024-03-31 21:00:00                  28.487          0.973034
# 2182 2024-03-31 22:00:00                  28.555          0.972540
# 2183 2024-03-31 23:00:00                  27.944          0.972353
#
#       Wind speed | (m/s)  Power generated by system | (MW)
# 0                 10.868                          53.18100
# ...

# %%
X_val = mon_3[['Air temperature | (°C)', 'Pressure | (atm)', 'Wind speed | (m/s)']]
y_pred_val = model.predict(X_val)
print(y_pred_val)
# Out:
# [52.261099 51.971086 55.674574 ... 14.777309 13.193791 12.849829]

# %%
r2 = r2_score(mon_3['Power generated by system | (MW)'], y_pred_val)
print(f"R2 score: {r2}")
# Out:
# R2 score: 0.9995942605273321
